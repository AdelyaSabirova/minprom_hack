# %%
import pandas as pd
import numpy as np
from pathlib import Path
from collections import defaultdict
from tqdm import tqdm
import shutil

import albumentations as A
import cv2
import matplotlib.pyplot as plt

# %%
img_p = Path('/home/alex/nkbtech/hdd1/Datasets/train_dataset_minpromtorg_train_dataset/photo/1-helicopter/images/27042021_¡¿¿» óÑαΓ«½ÑΓ@ds-0067.jpg')
img = cv2.imread(str(img_p), cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')
print(img.shape)
# Out:
# (512, 640)

# %%
aug = A.InvertImg(always_apply=True)
inverted_img = aug(image=img)['image']
plt.imshow(inverted_img, cmap='gray')

# %%
offline_inverted = cv2.imread(str(img_p.parent/(img_p.stem+'-inv.jpg')), cv2.IMREAD_GRAYSCALE)
plt.imshow(offline_inverted, cmap='gray')

# %%
np.all(inverted_img == offline_inverted)
# Out:
# False

# %%
plt.imshow(inverted_img - offline_inverted, cmap='gray')

# %%
# IR by leaving only red channel

img = cv2.imread('/home/alex/nkbtech/hdd4/Datasets/people/CrowdHuman/test/images/1066405,2ff1d00066a506a2.jpg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(img[:, :, 2], cmap='gray')
